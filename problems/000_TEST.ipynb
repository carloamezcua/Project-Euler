# %%
import euler_lib as euler

# %%
cadena = """
12 34 56 78 90
09 87 65 43 21
21 43 65 87 09
90 78 56 34 12
10 29 38 47 56
"""

numeros = [int(i) for i in cadena.split()]

filas = 5
columnas = 5

matriz = []

for i in range(0, len(numeros), columnas):
    fila = numeros[i: columnas + i]
    matriz.append(fila)


for i in range(len(matriz)):
    print(matriz[i])
# Out:
# [12, 34, 56, 78, 90]
# [9, 87, 65, 43, 21]
# [21, 43, 65, 87, 9]
# [90, 78, 56, 34, 12]
# [10, 29, 38, 47, 56]
