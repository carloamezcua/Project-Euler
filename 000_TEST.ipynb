# %%
import euler_lib as euler

# %%
factores = euler.factores_primos(20)
print(factores)
# Out:
# [2, 2, 5]

# %%
max_factores = {}
for i in range(1, 21):
    factores = euler.factores_primos(i)
    potencias_i = potencias_factores(factores)
    #print(f"i: {i}, factores: {factores}, potencias: {potencias_i}")
    for f in potencias_i:
        if f not in max_factores:
            max_factores[f] = potencias_i[f]
        else:
            if potencias_i[f] > max_factores[f]:
                max_factores[f] = potencias_i[f]

resultado = 1
for f in max_factores:
    resultado *= f ** max_factores[f]

print(resultado)
# Out:
# 232792560
